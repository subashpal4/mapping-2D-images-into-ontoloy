# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 7.4 MB/s eta 0:00:00
# ...

# %%
## importing required libraries
import os
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
## connecting to the google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_path_img = "./yolo_data/images/train/"
train_path_label = "./yolo_data/labels/train/"
val_path_img = "./yolo_data/images/val/"
val_path_label = "./yolo_data/labels/val/"
test_path = "./yolo_data/test"

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# Training

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolov8/data/data.yaml epochs=10 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=robotdetection
# Out:
# Ultralytics YOLOv8.0.153 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolov8/data/data.yaml epochs=50 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=robotdetection
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 223MB/s]
# Ultralytics YOLOv8.0.154 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Inferencing

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/robotdetection5/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/data/test/images
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients
#
# image 1/87 /content/drive/MyDrive/yolov8/data/test/images/IMG_0197_JPG.rf.7464bdb89d0992da5f8e3b235320b91f.jpg: 640x640 1 Conveyer, 2 Robotcobots, 16.3ms
# image 2/87 /content/drive/MyDrive/yolov8/data/test/images/IMG_0199_JPG.rf.894749a61fc621277221025b17b94b88.jpg: 640x640 1 Conveyer, 2 Robotcobots, 16.4ms
# image 3/87 /content/drive/MyDrive/yolov8/data/test/images/IMG_0211_JPG.rf.e1509af181e2fefd0913d431c4aab528.jpg: 640x640 1 Conveyer, 2 Robotcobots, 16.3ms
# image 4/87 /content/drive/MyDrive/yolov8/data/test/images/IMG_0221_JPG.rf.7e840e2505b0be353dbfc74c364fd774.jpg: 640x640 1 Conveyer, 1 Robotcobot, 16.3ms
# image 5/87 /content/drive/MyDrive/yolov8/data/test/images/IMG_0228_JPG.rf.75269f2ad0b059012c70cc3f8ef3256e.jpg: 640x640 1 Conveyer, 3 Robotcobots, 16.3ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolov8/output
